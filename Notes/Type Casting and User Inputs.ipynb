# %% [markdown]
# ## Typecasting = the process of converting a variable form one data type to another str(), int(), float(), bool()

# %%
name = 'Nehan'
age = 18
gpa = 4.3
is_studnet = True

age = str(age)
print(type(age))

# %% [markdown]
# ## input() =  A function that prompts the user to enter data
#
# #### The entered data will always return as string, using type casting we can convert it into other variables

# %%
name = input('What is your name?: ')
age = int(input('How old are you?: '))
age = int(age)
age = age + 1
print(f'Hello {name}!')
print('Happy birthday')
print(f'You are {age} years old.')
